# %%
# Import necessary libraries
import pandas as pd
from pathlib import Path
import os
from datasets import Dataset, Image, ClassLabel
import random
import shutil
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization, Activation, add, GlobalAveragePooling2D, Dense

# Initialize empty lists to store file names and labels
file_names = []
labels = []

# Specify the directory using os.path.join to handle paths across different OS
directory = 'C:\\Users\\Noura\\Downloads\\Untitled Folder 1\\dataset'

# Iterate through all image files in the specified directory
for file in tqdm(sorted(Path(directory).glob('*/*.*'))):
    label = os.path.basename(os.path.dirname(file))  # Extract the label from the file path
    labels.append(label)  # Add the label to the list
    file_names.append(str(file))  # Add the file path to the list

# Print the total number of file names and labels
print(len(file_names), len(labels))

# Create a pandas dataframe from the collected file names and labels
df = pd.DataFrame.from_dict({"image": file_names, "label": labels})
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       3 from pathlib import Path
#       4 import os
# ----> 5 from datasets import Dataset, Image, ClassLabel
#       6 import random
#       7 import shutil
#
# ModuleNotFoundError: No module named 'datasets'

# %%
df.head()
# Out:
#                                                image label
# 0  C:\Users\Noura\Downloads\Untitled Folder 1\dat...   dew
# 1  C:\Users\Noura\Downloads\Untitled Folder 1\dat...   dew
# 2  C:\Users\Noura\Downloads\Untitled Folder 1\dat...   dew
# 3  C:\Users\Noura\Downloads\Untitled Folder 1\dat...   dew
# 4  C:\Users\Noura\Downloads\Untitled Folder 1\dat...   dew

# %%
df['label'].unique()
# Out:
# array(['dew', 'fogsmog', 'glaze', 'rime', 'sandstorm'], dtype=object)

# %%
dataset = Dataset.from_pandas(df).cast_column("image", Image())

# %%
# Define the desired order of labels
labels_list = ['rime', 'fogsmog', 'dew', 'sandstorm', 'glaze']

# Initialize empty dictionaries to map labels to IDs and vice versa
label2id, id2label = dict(), dict()

# Assign IDs based on the desired order
for i, label in enumerate(labels_list):
    label2id[label] = i  # Map the label to its corresponding ID
    id2label[i] = label  # Map the ID to its corresponding label

# Print the resulting dictionaries for reference
print("Mapping of IDs to Labels:", id2label, '\n')
print("Mapping of Labels to IDs:", label2id)
# Out:
# Mapping of IDs to Labels: {0: 'rime', 1: 'fogsmog', 2: 'dew', 3: 'sandstorm', 4: 'glaze'}
#
# Mapping of Labels to IDs: {'rime': 0, 'fogsmog': 1, 'dew': 2, 'sandstorm': 3, 'glaze': 4}

# %%
labels_list
# Out:
# ['rime', 'fogsmog', 'dew', 'sandstorm', 'glaze']

# %%
root_directory = r'C:\\Users\\Noura\\Downloads\\Untitled Folder 1\\dataset\\'
train_directory = os.path.join(root_directory, 'train')
test_directory = os.path.join(root_directory, 'test')

os.makedirs(train_directory, exist_ok=True)
os.makedirs(test_directory, exist_ok=True)

for t in labels_list:
    origin = os.path.join(root_directory, t)
    train_class_directory = os.path.join(train_directory, t)
    test_class_directory = os.path.join(test_directory, t)
    
    os.makedirs(train_class_directory, exist_ok=True)
    os.makedirs(test_class_directory, exist_ok=True)

    for root, dirs, files in os.walk(origin):
        random.shuffle(files)
        train_list = files[:int((0.75) * len(files))]
        test_list = files[int((0.75) * len(files)):]

        for f in train_list:
            shutil.copy(os.path.join(origin, f), os.path.join(train_class_directory, f))

        for f in test_list:
            shutil.copy(os.path.join(origin, f), os.path.join(test_class_directory, f))

# %%
# Checking the total number of files

print("TRAIN DATASET")
print("_____________")
sum = 0
for root, dirs, files in os.walk('C:\\Users\\Noura\\Downloads\\Untitled Folder 1\\dataset\\train\\'):
    if files != []:
        print(root, "-->", len(files))
        sum += len(files)

print("_____________")
print("TOTAL = ", sum)
print()
print()

print("TEST DATASET")
print("_____________")
sum = 0
for root, dirs, files in os.walk('C:\\Users\\Noura\\Downloads\\Untitled Folder 1\\dataset\\test\\'):
    if files != []:
        print(root, "-->", len(files))
        sum += len(files)

print("_____________")
print("TOTAL = ", sum)
print()
# Out:
# TRAIN DATASET
# _____________
# C:\Users\Noura\Downloads\Untitled Folder 1\dataset\train\dew --> 523
# C:\Users\Noura\Downloads\Untitled Folder 1\dataset\train\fogsmog --> 638
# C:\Users\Noura\Downloads\Untitled Folder 1\dataset\train\glaze --> 479
# C:\Users\Noura\Downloads\Untitled Folder 1\dataset\train\rime --> 870
# C:\Users\Noura\Downloads\Untitled Folder 1\dataset\train\sandstorm --> 519
# _____________
# TOTAL =  3029
#
#
# TEST DATASET
# _____________
# C:\Users\Noura\Downloads\Untitled Folder 1\dataset\test\dew --> 175
# C:\Users\Noura\Downloads\Untitled Folder 1\dataset\test\fogsmog --> 213
# C:\Users\Noura\Downloads\Untitled Folder 1\dataset\test\glaze --> 160
# C:\Users\Noura\Downloads\Untitled Folder 1\dataset\test\rime --> 290
# C:\Users\Noura\Downloads\Untitled Folder 1\dataset\test\sandstorm --> 173
# _____________
# TOTAL =  1011

# %%
# Input layer
input_tensor = Input(shape=(224, 224, 3))  # Adjust input shape as needed

# Initial Conv and MaxPooling
x = Conv2D(32, (7, 7), strides=(2, 2), padding='same')(input_tensor)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

# Residual blocks
def residual_block(x, filters, kernel_size=3, stride=1):
    shortcut = x

    x = Conv2D(filters[0], (1, 1), strides=(stride, stride), padding='valid')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters[1], (kernel_size, kernel_size), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters[2], (1, 1), padding='valid')(x)
    x = BatchNormalization()(x)

    shortcut = Conv2D(filters[2], (1, 1), strides=(stride, stride), padding='valid')(shortcut)
    shortcut = BatchNormalization()(shortcut)

    x = add([x, shortcut])
    x = Activation('relu')(x)

    return x

# Conv2_x
x = residual_block(x, [32, 32, 64])
x = residual_block(x, [32, 32, 64])
x = residual_block(x, [32, 32, 64])

# Conv3_x
x = residual_block(x, [64, 64, 128])
x = residual_block(x, [64, 64, 128])
x = residual_block(x, [64, 64, 128])

# Conv4_x
x = residual_block(x, [128, 128, 256])
x = residual_block(x, [128, 128, 256])
x = residual_block(x, [128, 128, 256])

# Conv5_x
x = residual_block(x, [256, 256, 512])
x = residual_block(x, [256, 256, 512])
x = residual_block(x, [256, 256, 512])

# Global Average Pooling
x = GlobalAveragePooling2D()(x)

# Fully Connected layer
x = Dense(512, activation='relu')(x)

# Softmax layer
output_tensor = Dense(4, activation='softmax')(x)  # Assuming 4 classes

# Instantiate the model
model = Model(inputs=input_tensor, outputs=output_tensor)

# Print model summary
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_98 (Conv2D)          (None, 112, 112, 32)         4736      ['input_3[0][0]']
#
#  batch_normalization_98 (Ba  (None, 112, 112, 32)         128       ['conv2d_98[0][0]']
#  tchNormalization)
#
#  activation_74 (Activation)  (None, 112, 112, 32)         0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  max_pooling2d_2 (MaxPoolin  (None, 56, 56, 32)           0         ['activation_74[0][0]']
#  g2D)
#
#  conv2d_99 (Conv2D)          (None, 56, 56, 32)           1056      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_99 (Ba  (None, 56, 56, 32)           128       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  activation_75 (Activation)  (None, 56, 56, 32)           0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  conv2d_100 (Conv2D)         (None, 56, 56, 32)           9248      ['activation_75[0][0]']
#
#  batch_normalization_100 (B  (None, 56, 56, 32)           128       ['conv2d_100[0][0]']
#  atchNormalization)
#
#  activation_76 (Activation)  (None, 56, 56, 32)           0         ['batch_normalization_100[0][0
#                                                                     ]']
#
#  conv2d_101 (Conv2D)         (None, 56, 56, 64)           2112      ['activation_76[0][0]']
#
#  conv2d_102 (Conv2D)         (None, 56, 56, 64)           2112      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_101 (B  (None, 56, 56, 64)           256       ['conv2d_101[0][0]']
#  atchNormalization)
#
#  batch_normalization_102 (B  (None, 56, 56, 64)           256       ['conv2d_102[0][0]']
#  atchNormalization)
#
#  add_24 (Add)                (None, 56, 56, 64)           0         ['batch_normalization_101[0][0
#                                                                     ]',
#                                                                      'batch_normalization_102[0][0
#                                                                     ]']
#
#  activation_77 (Activation)  (None, 56, 56, 64)           0         ['add_24[0][0]']
#
#  conv2d_103 (Conv2D)         (None, 56, 56, 32)           2080      ['activation_77[0][0]']
#
#  batch_normalization_103 (B  (None, 56, 56, 32)           128       ['conv2d_103[0][0]']
#  atchNormalization)
#
#  activation_78 (Activation)  (None, 56, 56, 32)           0         ['batch_normalization_103[0][0
#                                                                     ]']
#
#  conv2d_104 (Conv2D)         (None, 56, 56, 32)           9248      ['activation_78[0][0]']
#
#  batch_normalization_104 (B  (None, 56, 56, 32)           128       ['conv2d_104[0][0]']
#  atchNormalization)
#
#  activation_79 (Activation)  (None, 56, 56, 32)           0         ['batch_normalization_104[0][0
#                                                                     ]']
#
#  conv2d_105 (Conv2D)         (None, 56, 56, 64)           2112      ['activation_79[0][0]']
#
#  conv2d_106 (Conv2D)         (None, 56, 56, 64)           4160      ['activation_77[0][0]']
#
#  batch_normalization_105 (B  (None, 56, 56, 64)           256       ['conv2d_105[0][0]']
#  atchNormalization)
#
#  batch_normalization_106 (B  (None, 56, 56, 64)           256       ['conv2d_106[0][0]']
#  atchNormalization)
#
#  add_25 (Add)                (None, 56, 56, 64)           0         ['batch_normalization_105[0][0
#                                                                     ]',
#                                                                      'batch_normalization_106[0][0
#                                                                     ]']
#
#  activation_80 (Activation)  (None, 56, 56, 64)           0         ['add_25[0][0]']
#
#  conv2d_107 (Conv2D)         (None, 56, 56, 32)           2080      ['activation_80[0][0]']
#
#  batch_normalization_107 (B  (None, 56, 56, 32)           128       ['conv2d_107[0][0]']
#  atchNormalization)
#
#  activation_81 (Activation)  (None, 56, 56, 32)           0         ['batch_normalization_107[0][0
#                                                                     ]']
#
#  conv2d_108 (Conv2D)         (None, 56, 56, 32)           9248      ['activation_81[0][0]']
#
#  batch_normalization_108 (B  (None, 56, 56, 32)           128       ['conv2d_108[0][0]']
#  atchNormalization)
#
#  activation_82 (Activation)  (None, 56, 56, 32)           0         ['batch_normalization_108[0][0
#                                                                     ]']
#
#  conv2d_109 (Conv2D)         (None, 56, 56, 64)           2112      ['activation_82[0][0]']
#
#  conv2d_110 (Conv2D)         (None, 56, 56, 64)           4160      ['activation_80[0][0]']
#
#  batch_normalization_109 (B  (None, 56, 56, 64)           256       ['conv2d_109[0][0]']
#  atchNormalization)
#
#  batch_normalization_110 (B  (None, 56, 56, 64)           256       ['conv2d_110[0][0]']
#  atchNormalization)
#
#  add_26 (Add)                (None, 56, 56, 64)           0         ['batch_normalization_109[0][0
#                                                                     ]',
#                                                                      'batch_normalization_110[0][0
#                                                                     ]']
#
#  activation_83 (Activation)  (None, 56, 56, 64)           0         ['add_26[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 56, 56, 64)           4160      ['activation_83[0][0]']
#
#  batch_normalization_111 (B  (None, 56, 56, 64)           256       ['conv2d_111[0][0]']
#  atchNormalization)
#
#  activation_84 (Activation)  (None, 56, 56, 64)           0         ['batch_normalization_111[0][0
#                                                                     ]']
#
#  conv2d_112 (Conv2D)         (None, 56, 56, 64)           36928     ['activation_84[0][0]']
#
#  batch_normalization_112 (B  (None, 56, 56, 64)           256       ['conv2d_112[0][0]']
#  atchNormalization)
#
#  activation_85 (Activation)  (None, 56, 56, 64)           0         ['batch_normalization_112[0][0
#                                                                     ]']
#
#  conv2d_113 (Conv2D)         (None, 56, 56, 128)          8320      ['activation_85[0][0]']
#
#  conv2d_114 (Conv2D)         (None, 56, 56, 128)          8320      ['activation_83[0][0]']
#
#  batch_normalization_113 (B  (None, 56, 56, 128)          512       ['conv2d_113[0][0]']
#  atchNormalization)
#
#  batch_normalization_114 (B  (None, 56, 56, 128)          512       ['conv2d_114[0][0]']
#  atchNormalization)
#
#  add_27 (Add)                (None, 56, 56, 128)          0         ['batch_normalization_113[0][0
#                                                                     ]',
#                                                                      'batch_normalization_114[0][0
#                                                                     ]']
#
#  activation_86 (Activation)  (None, 56, 56, 128)          0         ['add_27[0][0]']
#
#  conv2d_115 (Conv2D)         (None, 56, 56, 64)           8256      ['activation_86[0][0]']
#
#  batch_normalization_115 (B  (None, 56, 56, 64)           256       ['conv2d_115[0][0]']
#  atchNormalization)
#
#  activation_87 (Activation)  (None, 56, 56, 64)           0         ['batch_normalization_115[0][0
#                                                                     ]']
#
#  conv2d_116 (Conv2D)         (None, 56, 56, 64)           36928     ['activation_87[0][0]']
#
#  batch_normalization_116 (B  (None, 56, 56, 64)           256       ['conv2d_116[0][0]']
#  atchNormalization)
#
#  activation_88 (Activation)  (None, 56, 56, 64)           0         ['batch_normalization_116[0][0
#                                                                     ]']
#
#  conv2d_117 (Conv2D)         (None, 56, 56, 128)          8320      ['activation_88[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 56, 56, 128)          16512     ['activation_86[0][0]']
#
#  batch_normalization_117 (B  (None, 56, 56, 128)          512       ['conv2d_117[0][0]']
#  atchNormalization)
#
#  batch_normalization_118 (B  (None, 56, 56, 128)          512       ['conv2d_118[0][0]']
#  atchNormalization)
#
#  add_28 (Add)                (None, 56, 56, 128)          0         ['batch_normalization_117[0][0
#                                                                     ]',
#                                                                      'batch_normalization_118[0][0
#                                                                     ]']
#
#  activation_89 (Activation)  (None, 56, 56, 128)          0         ['add_28[0][0]']
#
#  conv2d_119 (Conv2D)         (None, 56, 56, 64)           8256      ['activation_89[0][0]']
#
#  batch_normalization_119 (B  (None, 56, 56, 64)           256       ['conv2d_119[0][0]']
#  atchNormalization)
#
#  activation_90 (Activation)  (None, 56, 56, 64)           0         ['batch_normalization_119[0][0
#                                                                     ]']
#
#  conv2d_120 (Conv2D)         (None, 56, 56, 64)           36928     ['activation_90[0][0]']
#
#  batch_normalization_120 (B  (None, 56, 56, 64)           256       ['conv2d_120[0][0]']
#  atchNormalization)
#
#  activation_91 (Activation)  (None, 56, 56, 64)           0         ['batch_normalization_120[0][0
#                                                                     ]']
#
#  conv2d_121 (Conv2D)         (None, 56, 56, 128)          8320      ['activation_91[0][0]']
#
#  conv2d_122 (Conv2D)         (None, 56, 56, 128)          16512     ['activation_89[0][0]']
#
#  batch_normalization_121 (B  (None, 56, 56, 128)          512       ['conv2d_121[0][0]']
#  atchNormalization)
#
#  batch_normalization_122 (B  (None, 56, 56, 128)          512       ['conv2d_122[0][0]']
#  atchNormalization)
#
#  add_29 (Add)                (None, 56, 56, 128)          0         ['batch_normalization_121[0][0
#                                                                     ]',
#                                                                      'batch_normalization_122[0][0
#                                                                     ]']
#
#  activation_92 (Activation)  (None, 56, 56, 128)          0         ['add_29[0][0]']
#
#  conv2d_123 (Conv2D)         (None, 56, 56, 128)          16512     ['activation_92[0][0]']
#
#  batch_normalization_123 (B  (None, 56, 56, 128)          512       ['conv2d_123[0][0]']
#  atchNormalization)
#
#  activation_93 (Activation)  (None, 56, 56, 128)          0         ['batch_normalization_123[0][0
#                                                                     ]']
#
#  conv2d_124 (Conv2D)         (None, 56, 56, 128)          147584    ['activation_93[0][0]']
#
#  batch_normalization_124 (B  (None, 56, 56, 128)          512       ['conv2d_124[0][0]']
#  atchNormalization)
#
#  activation_94 (Activation)  (None, 56, 56, 128)          0         ['batch_normalization_124[0][0
#                                                                     ]']
#
#  conv2d_125 (Conv2D)         (None, 56, 56, 256)          33024     ['activation_94[0][0]']
#
#  conv2d_126 (Conv2D)         (None, 56, 56, 256)          33024     ['activation_92[0][0]']
#
#  batch_normalization_125 (B  (None, 56, 56, 256)          1024      ['conv2d_125[0][0]']
#  atchNormalization)
#
#  batch_normalization_126 (B  (None, 56, 56, 256)          1024      ['conv2d_126[0][0]']
#  atchNormalization)
#
#  add_30 (Add)                (None, 56, 56, 256)          0         ['batch_normalization_125[0][0
#                                                                     ]',
#                                                                      'batch_normalization_126[0][0
#                                                                     ]']
#
#  activation_95 (Activation)  (None, 56, 56, 256)          0         ['add_30[0][0]']
#
#  conv2d_127 (Conv2D)         (None, 56, 56, 128)          32896     ['activation_95[0][0]']
#
#  batch_normalization_127 (B  (None, 56, 56, 128)          512       ['conv2d_127[0][0]']
#  atchNormalization)
#
#  activation_96 (Activation)  (None, 56, 56, 128)          0         ['batch_normalization_127[0][0
#                                                                     ]']
#
#  conv2d_128 (Conv2D)         (None, 56, 56, 128)          147584    ['activation_96[0][0]']
#
#  batch_normalization_128 (B  (None, 56, 56, 128)          512       ['conv2d_128[0][0]']
#  atchNormalization)
#
#  activation_97 (Activation)  (None, 56, 56, 128)          0         ['batch_normalization_128[0][0
#                                                                     ]']
#
#  conv2d_129 (Conv2D)         (None, 56, 56, 256)          33024     ['activation_97[0][0]']
#
#  conv2d_130 (Conv2D)         (None, 56, 56, 256)          65792     ['activation_95[0][0]']
#
#  batch_normalization_129 (B  (None, 56, 56, 256)          1024      ['conv2d_129[0][0]']
#  atchNormalization)
#
#  batch_normalization_130 (B  (None, 56, 56, 256)          1024      ['conv2d_130[0][0]']
#  atchNormalization)
#
#  add_31 (Add)                (None, 56, 56, 256)          0         ['batch_normalization_129[0][0
#                                                                     ]',
#                                                                      'batch_normalization_130[0][0
#                                                                     ]']
#
#  activation_98 (Activation)  (None, 56, 56, 256)          0         ['add_31[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 56, 56, 128)          32896     ['activation_98[0][0]']
#
#  batch_normalization_131 (B  (None, 56, 56, 128)          512       ['conv2d_131[0][0]']
#  atchNormalization)
#
#  activation_99 (Activation)  (None, 56, 56, 128)          0         ['batch_normalization_131[0][0
#                                                                     ]']
#
#  conv2d_132 (Conv2D)         (None, 56, 56, 128)          147584    ['activation_99[0][0]']
#
#  batch_normalization_132 (B  (None, 56, 56, 128)          512       ['conv2d_132[0][0]']
#  atchNormalization)
#
#  activation_100 (Activation  (None, 56, 56, 128)          0         ['batch_normalization_132[0][0
#  )                                                                  ]']
#
#  conv2d_133 (Conv2D)         (None, 56, 56, 256)          33024     ['activation_100[0][0]']
#
#  conv2d_134 (Conv2D)         (None, 56, 56, 256)          65792     ['activation_98[0][0]']
#
#  batch_normalization_133 (B  (None, 56, 56, 256)          1024      ['conv2d_133[0][0]']
#  atchNormalization)
#
#  batch_normalization_134 (B  (None, 56, 56, 256)          1024      ['conv2d_134[0][0]']
#  atchNormalization)
#
#  add_32 (Add)                (None, 56, 56, 256)          0         ['batch_normalization_133[0][0
#                                                                     ]',
#                                                                      'batch_normalization_134[0][0
#                                                                     ]']
#
#  activation_101 (Activation  (None, 56, 56, 256)          0         ['add_32[0][0]']
#  )
#
#  conv2d_135 (Conv2D)         (None, 56, 56, 256)          65792     ['activation_101[0][0]']
#
#  batch_normalization_135 (B  (None, 56, 56, 256)          1024      ['conv2d_135[0][0]']
#  atchNormalization)
#
#  activation_102 (Activation  (None, 56, 56, 256)          0         ['batch_normalization_135[0][0
#  )                                                                  ]']
#
#  conv2d_136 (Conv2D)         (None, 56, 56, 256)          590080    ['activation_102[0][0]']
#
#  batch_normalization_136 (B  (None, 56, 56, 256)          1024      ['conv2d_136[0][0]']
#  atchNormalization)
#
#  activation_103 (Activation  (None, 56, 56, 256)          0         ['batch_normalization_136[0][0
#  )                                                                  ]']
#
#  conv2d_137 (Conv2D)         (None, 56, 56, 512)          131584    ['activation_103[0][0]']
#
#  conv2d_138 (Conv2D)         (None, 56, 56, 512)          131584    ['activation_101[0][0]']
#
#  batch_normalization_137 (B  (None, 56, 56, 512)          2048      ['conv2d_137[0][0]']
#  atchNormalization)
#
#  batch_normalization_138 (B  (None, 56, 56, 512)          2048      ['conv2d_138[0][0]']
#  atchNormalization)
#
#  add_33 (Add)                (None, 56, 56, 512)          0         ['batch_normalization_137[0][0
#                                                                     ]',
#                                                                      'batch_normalization_138[0][0
#                                                                     ]']
#
#  activation_104 (Activation  (None, 56, 56, 512)          0         ['add_33[0][0]']
#  )
#
#  conv2d_139 (Conv2D)         (None, 56, 56, 256)          131328    ['activation_104[0][0]']
#
#  batch_normalization_139 (B  (None, 56, 56, 256)          1024      ['conv2d_139[0][0]']
#  atchNormalization)
#
#  activation_105 (Activation  (None, 56, 56, 256)          0         ['batch_normalization_139[0][0
#  )                                                                  ]']
#
#  conv2d_140 (Conv2D)         (None, 56, 56, 256)          590080    ['activation_105[0][0]']
#
#  batch_normalization_140 (B  (None, 56, 56, 256)          1024      ['conv2d_140[0][0]']
#  atchNormalization)
#
#  activation_106 (Activation  (None, 56, 56, 256)          0         ['batch_normalization_140[0][0
#  )                                                                  ]']
#
#  conv2d_141 (Conv2D)         (None, 56, 56, 512)          131584    ['activation_106[0][0]']
#
#  conv2d_142 (Conv2D)         (None, 56, 56, 512)          262656    ['activation_104[0][0]']
#
#  batch_normalization_141 (B  (None, 56, 56, 512)          2048      ['conv2d_141[0][0]']
#  atchNormalization)
#
#  batch_normalization_142 (B  (None, 56, 56, 512)          2048      ['conv2d_142[0][0]']
#  atchNormalization)
#
#  add_34 (Add)                (None, 56, 56, 512)          0         ['batch_normalization_141[0][0
#                                                                     ]',
#                                                                      'batch_normalization_142[0][0
#                                                                     ]']
#
#  activation_107 (Activation  (None, 56, 56, 512)          0         ['add_34[0][0]']
#  )
#
#  conv2d_143 (Conv2D)         (None, 56, 56, 256)          131328    ['activation_107[0][0]']
#
#  batch_normalization_143 (B  (None, 56, 56, 256)          1024      ['conv2d_143[0][0]']
#  atchNormalization)
#
#  activation_108 (Activation  (None, 56, 56, 256)          0         ['batch_normalization_143[0][0
#  )                                                                  ]']
#
#  conv2d_144 (Conv2D)         (None, 56, 56, 256)          590080    ['activation_108[0][0]']
#
#  batch_normalization_144 (B  (None, 56, 56, 256)          1024      ['conv2d_144[0][0]']
#  atchNormalization)
#
#  activation_109 (Activation  (None, 56, 56, 256)          0         ['batch_normalization_144[0][0
#  )                                                                  ]']
#
#  conv2d_145 (Conv2D)         (None, 56, 56, 512)          131584    ['activation_109[0][0]']
#
#  conv2d_146 (Conv2D)         (None, 56, 56, 512)          262656    ['activation_107[0][0]']
#
#  batch_normalization_145 (B  (None, 56, 56, 512)          2048      ['conv2d_145[0][0]']
#  atchNormalization)
#
#  batch_normalization_146 (B  (None, 56, 56, 512)          2048      ['conv2d_146[0][0]']
#  atchNormalization)
#
#  add_35 (Add)                (None, 56, 56, 512)          0         ['batch_normalization_145[0][0
#                                                                     ]',
#                                                                      'batch_normalization_146[0][0
#                                                                     ]']
#
#  activation_110 (Activation  (None, 56, 56, 512)          0         ['add_35[0][0]']
#  )
#
#  global_average_pooling2d_2  (None, 512)                  0         ['activation_110[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 512)                  262656    ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dense_5 (Dense)             (None, 4)                    2052      ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 4490692 (17.13 MB)
# Trainable params: 4473348 (17.06 MB)
# Non-trainable params: 17344 (67.75 KB)
# __________________________________________________________________________________________________

# %%
from sklearn.preprocessing import LabelEncoder

# Root directory where your dataset is stored
root_directory = 'C:\\Users\\Noura\\Downloads\\Untitled Folder 1\\dataset\\'

# Mapping of labels to specific integers
specific_mapping = {'rime': 0, 'fogsmog': 1, 'dew': 2, 'sandstorm': 3, 'glaze': 4}

# Initialize empty lists to store file paths and labels for train and test sets
train_file_paths = []
train_labels = []
test_file_paths = []
test_labels = []

# Function to map original labels to specific integers based on the mapping
def map_labels(label):
    return specific_mapping[label]

# Function to gather file paths and labels for a specific directory (train or test)
def gather_files_and_labels(directory, file_paths, labels):
    for class_name in os.listdir(directory):
        class_dir = os.path.join(directory, class_name)
        if os.path.isdir(class_dir):
            for file_name in os.listdir(class_dir):
                file_path = os.path.join(class_dir, file_name)
                file_paths.append(file_path)
                labels.append(class_name)  # Store the corresponding label

# Gathering files and labels for training and testing data separately
train_directory = os.path.join(root_directory, 'train')
test_directory = os.path.join(root_directory, 'test')
gather_files_and_labels(train_directory, train_file_paths, train_labels)
gather_files_and_labels(test_directory, test_file_paths, test_labels)

# Map the original labels to the specific integers based on the mapping
encoded_train_labels = list(map(map_labels, train_labels))
encoded_test_labels = list(map(map_labels, test_labels))

# Create pandas DataFrames with image paths, original labels, and encoded labels for train and test sets
train_df = pd.DataFrame({'image': train_file_paths, 'label': train_labels, 'encoded_label': encoded_train_labels})
test_df = pd.DataFrame({'image': test_file_paths, 'label': test_labels, 'encoded_label': encoded_test_labels})

# Show the DataFrames containing file paths, original labels, and encoded labels for train and test sets
print("Train Data:")
print(train_df)
print("\nTest Data:")
print(test_df)
# Out:
# Train Data:
#                                                   image      label  \
# 0     C:\Users\Noura\Downloads\Untitled Folder 1\dat...        dew
# 1     C:\Users\Noura\Downloads\Untitled Folder 1\dat...        dew
# 2     C:\Users\Noura\Downloads\Untitled Folder 1\dat...        dew
# 3     C:\Users\Noura\Downloads\Untitled Folder 1\dat...        dew
# 4     C:\Users\Noura\Downloads\Untitled Folder 1\dat...        dew
# ...                                                 ...        ...
# 3024  C:\Users\Noura\Downloads\Untitled Folder 1\dat...  sandstorm
# 3025  C:\Users\Noura\Downloads\Untitled Folder 1\dat...  sandstorm
# 3026  C:\Users\Noura\Downloads\Untitled Folder 1\dat...  sandstorm
# 3027  C:\Users\Noura\Downloads\Untitled Folder 1\dat...  sandstorm
# 3028  C:\Users\Noura\Downloads\Untitled Folder 1\dat...  sandstorm
#
#       encoded_label
# 0                 2
# 1                 2
# 2                 2
# 3                 2
# 4                 2
# ...             ...
# 3024              3
# 3025              3
# 3026              3
# 3027              3
# 3028              3
#
# [3029 rows x 3 columns]
#
# Test Data:
#                                                   image      label  \
# 0     C:\Users\Noura\Downloads\Untitled Folder 1\dat...        dew
# 1     C:\Users\Noura\Downloads\Untitled Folder 1\dat...        dew
# 2     C:\Users\Noura\Downloads\Untitled Folder 1\dat...        dew
# 3     C:\Users\Noura\Downloads\Untitled Folder 1\dat...        dew
# 4     C:\Users\Noura\Downloads\Untitled Folder 1\dat...        dew
# ...                                                 ...        ...
# 1006  C:\Users\Noura\Downloads\Untitled Folder 1\dat...  sandstorm
# 1007  C:\Users\Noura\Downloads\Untitled Folder 1\dat...  sandstorm
# 1008  C:\Users\Noura\Downloads\Untitled Folder 1\dat...  sandstorm
# 1009  C:\Users\Noura\Downloads\Untitled Folder 1\dat...  sandstorm
# 1010  C:\Users\Noura\Downloads\Untitled Folder 1\dat...  sandstorm
#
#       encoded_label
# 0                 2
# 1                 2
# 2                 2
# 3                 2
# 4                 2
# ...             ...
# 1006              3
# 1007              3
# 1008              3
# 1009              3
# 1010              3
#
# [1011 rows x 3 columns]

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.metrics import categorical_accuracy

# Assuming you have training and validation data
# Replace X_train, y_train with your actual data
X_train = ...
y_train = ...

# Compile the model
model.compile(optimizer=Adam(lr=0.001),
              loss=categorical_crossentropy,
              metrics=[categorical_accuracy])

# Fit the model
history = model.fit(X_train, y_train, 
                    epochs=10,       # Adjust the number of epochs as needed
                    batch_size=32,   # Adjust the batch size as needed
                    validation_data=(X_val, y_val))

# Evaluate the model on test data if available
# Replace X_test and y_test with your actual test data
X_test = ...
y_test = ...

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
